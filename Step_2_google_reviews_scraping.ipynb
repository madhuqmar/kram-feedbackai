# %%
import pandas as pd

# %%
df = pd.read_csv("googlemaps-scraper/data/newest_gm_reviews_2025-01-13.csv", low_memory=False)

# %%
df.head()
# Out:
#                               id_review  \
# 0  ChdDSUhNMG9nS0VJQ0FnSUNfMVBHRTh3RRAB
# 1   ChZDSUhNMG9nS0VJQ0FnSURmMzVfZElnEAE
# 2   ChZDSUhNMG9nS0VJQ0FnSUQtb05tZ2J3EAE
# 3  ChdDSUhNMG9nS0VJQ0FnSURmNzVuTmtBRRAB
# 4  ChdDSUhNMG9nS0VJQ0FnSURmejlmUHhBRRAB
#
#                                              caption relative_date  \
# 0                                             Saiyda  13 hours ago
# 1  Good waxing and face massage service by Shaila...    2 days ago
# 2  I've been coming here for the last 10 years an...    2 days ago
# 3                                                NaN    2 days ago
# 4                                                NaN    2 days ago
#
#                   review_date              retrieval_date  rating  \
# 0  2025-01-13 15:59:48.626486  2025-01-13 15:59:48.626537     5.0
# 1  2025-01-11 15:59:48.626770  2025-01-13 15:59:48.626799     4.0
# 2  2025-01-11 15:59:48.626887  2025-01-13 15:59:48.626911     5.0
# ...

# %%
len(df)
# Out:
# 31149

# %%
df['place_id'].isna().sum()
# Out:
# 0

# %%
df['caption'].isna().sum()
# Out:
# 8093

# %%
df['caption'].notna().sum()
# Out:
# 23056

# %%
len(df['place_id'].unique())
# Out:
# 43

# %%
df["relative_date"].unique()
# Out:
# array(['13 hours ago', '2 days ago', '3 days ago', '6 days ago',
#        '2 weeks ago', '3 weeks ago', '4 weeks ago', '2 months ago',
#        '3 months ago', '4 months ago', '5 months ago', '6 months ago',
#        '7 months ago', '8 months ago', '9 months ago', '10 months ago',
#        '11 months ago', '2 years ago', '3 years ago', '4 years ago',
#        '5 years ago', '6 years ago', '7 years ago', '8 years ago',
#        '9 years ago', '12 years ago', '10 hours ago', '4 days ago',
#        '12 hours ago', '10 years ago', '5 days ago', '14 hours ago',
#        '8 hours ago', '9 hours ago', '11 hours ago', '15 hours ago',
#        '17 hours ago', '16 hours ago'], dtype=object)
