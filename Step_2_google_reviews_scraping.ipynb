# %%
import pandas as pd

# %%
df = pd.read_csv("googlemaps-scraper/data/newest_gm_reviews_2025-01-16.csv", low_memory=False)

# %%
df.head()
# Out:
#                               id_review  \
# 0  ChdDSUhNMG9nS0VJQ0FnSUNfenNuYjR3RRAB
# 1  ChdDSUhNMG9nS0VJQ0FnSUNfMVBHRTh3RRAB
# 2  ChdDSUhNMG9nS0VJQ0FnSUNfcU5PQm1nRRAB
# 3   ChZDSUhNMG9nS0VJQ0FnSURmMzVfZElnEAE
# 4   ChZDSUhNMG9nS0VJQ0FnSUQtb05tZ2J3EAE
#
#                                              caption relative_date  \
# 0  Super quick and great service. Reshmi and Roop...   8 hours ago
# 1                                             Saiyda    3 days ago
# 2  Excellent service and styling! 10/10 recommend...    4 days ago
# 3  Good waxing and face massage service by Shaila...    5 days ago
# 4  I've been coming here for the last 10 years an...    5 days ago
#
#                   review_date              retrieval_date  rating  \
# 0  2025-01-16 10:34:48.108683  2025-01-16 10:34:48.108740     5.0
# 1  2025-01-13 10:34:48.108849  2025-01-16 10:34:48.108884     5.0
# 2  2025-01-12 10:34:48.108970  2025-01-16 10:34:48.108996     5.0
# ...

# %%
len(df)
# Out:
# 114484

# %%
len(df['place_id'].unique())
# Out:
# 151

# %%
df['caption'].isna().sum()
# Out:
# np.int64(28123)

# %%
df['caption'].notna().sum()
# Out:
# np.int64(86361)

# %%
df["relative_date"].unique()
# Out:
# array(['8 hours ago', '3 days ago', '4 days ago', '5 days ago',
#        '6 days ago', '2 weeks ago', '3 weeks ago', '4 weeks ago',
#        '2 months ago', '3 months ago', '4 months ago', '5 months ago',
#        '6 months ago', '7 months ago', '8 months ago', '9 months ago',
#        '10 months ago', '11 months ago', '2 years ago', '3 years ago',
#        '4 years ago', '5 years ago', '6 years ago', '7 years ago',
#        '8 years ago', '9 years ago', '12 years ago', '3 hours ago',
#        '2 hours ago', '2 days ago', '10 years ago', 'an hour ago',
#        '4 hours ago', '13 hours ago', '7 hours ago', '5 hours ago',
#        '10 hours ago', '11 hours ago', '15 hours ago', '9 hours ago',
#        '14 hours ago', '17 hours ago', '11 years ago', '20 hours ago',
#        '18 hours ago', '19 hours ago', '21 hours ago', '23 hours ago',
#        '22 hours ago', '16 hours ago', '8 minutes ago', '27 minutes ago',
#        '6 hours ago', '20 minutes ago'], dtype=object)
